# %%
print(5,4,5,6,7,7,sep = "\")
# Out:
# 5	4	5	6	7	7
# Bad pipe message: %s [b'\xba\xec\xd0\xb2\t\x08F\xea\x87\xd6\xbaA\xda\xfd=\x94\x11\x0f ']
# Bad pipe message: %s [b'l\x9c4\x83qd\xab\xe5\xb6\xf7Eh\ta\x97\xad\xaa\xccHB\xc7;\xff2\xfea\x18\x97w\xbc\x00\x08\x13\x02\x13\x03\x13\x01\x00\xff\x01\x00\x00\x8f\x00\x00\x00']
# Bad pipe message: %s [b'\x0c\x00\x00\t127.0.0.1']
# ...
